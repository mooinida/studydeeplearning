# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,6,0.1)
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1,label="sin")
plt.plot(x,y2,linestyle="--",label="cos")
plt.xlabel("x")
plt.ylabel("y")
plt.title('sin & cos')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,6,0.1)
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1,label="sin")
plt.plot(x,y2,linestyle="--",label="cos")
plt.xlabel("x")
plt.ylabel("y")
plt.title('sin & cos')
plt.legend()
plt.show()

# %%
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
img=imread("C:/Users/andls/OneDrive/사진/스크린샷/2023-07-01 (1).png")
plt.imshow(img)
plt.show()

# %%
def AND(x1,x2):
    w1,w2,t=0.5,0.5,0.7
    tmp=x1*w1+x2*w2
    if tmp<=t:
        return 0
    elif tmp>t:
        return 1
print(AND(1,0))
print(AND(1,1))
AND(0,0)
# Out:
# 0
# 1
# 0

# %%
import numpy as np
x=np.array([0,1])
w=np.array([0.5,0.5])
b=-0.7
w*x
# Out:
# array([0. , 0.5])

# %%
np.sum(w*x)
# Out:
# 0.5

# %%
np.sum(w*x)+b
# Out:
# -0.19999999999999996

# %%
def AND(x1,x2):
    x=np.array([x1,x2])
    w=np.array([0.5,0.5])
    b=-0.7
    tmp=np.sum(w*x)+b
    if tmp<=0:
        return 0
    else:
        return 1
AND(2,3)
# Out:
# 1

# %%
AND(2,1)
# Out:
# 1

# %%
def NAND(x1,x2):
    x=np.array([x1,x2])
    w=np.array([-0.5,-0.5])
    b=0.7
    tmp=np.sum(w*x)+b
    print(tmp)
    if tmp<=0:
        return 0
    else:
        return 1
NAND(2,3)
# Out:
# -1.8
# 0

# %%
NAND(0,0)
# Out:
# 0.7
# 1

# %%
def OR(x1,x2):
    x=np.array([x1,x2])
    w=np.array([0.5,0.5])
    b=-0.2
    tmp=np.sum(x*w)+b
    if tmp<=0:
        return 0
    else:
        return 1
